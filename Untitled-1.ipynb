# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# Create a sample DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Age': [25, 30, 35, 20, 28],
        'Score': [90, 80, 95, 85, 92]}
df = pd.DataFrame(data)

# Print the DataFrame
print(df)

# Calculate the mean score
mean_score = df['Score'].mean()
print(f'Mean score: {mean_score:.2f}')

# Filter the DataFrame to show only rows where Score > 90
high_scores = df[df['Score'] > 90]
print(high_scores)

# Plot a bar chart of the scores
plt.bar(df['Name'], df['Score'])
plt.xlabel('Name')
plt.ylabel('Score')
plt.title('Scores')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
#       Name  Age  Score
# 0    Alice   25     90
# 1      Bob   30     80
# 2  Charlie   35     95
# 3    David   20     85
# 4      Eve   28     92
# Mean score: 88.40
#       Name  Age  Score
# 2  Charlie   35     95
# 4      Eve   28     92
